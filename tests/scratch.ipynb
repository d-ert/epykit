# %%
import epykit

# %%
df = epykit.io.read_bismark_coverage("raw_data/GSM9212480_CONTROLDONOR3_REP1_1_val_1_bismark_bt2_pe.deduplicated.bismark.cov.gz", min_coverage=10)

df.head()
# Out:
# shape: (5, 7)
# ┌──────┬───────┬───────┬───────────┬────────────┬──────────────┬──────────┐
# │ chr  ┆ start ┆ end   ┆ beta      ┆ methylated ┆ unmethylated ┆ coverage │
# │ ---  ┆ ---   ┆ ---   ┆ ---       ┆ ---        ┆ ---          ┆ ---      │
# │ str  ┆ i64   ┆ i64   ┆ f64       ┆ i32        ┆ i32          ┆ i32      │
# ╞══════╪═══════╪═══════╪═══════════╪════════════╪══════════════╪══════════╡
# │ chr1 ┆ 13283 ┆ 13283 ┆ 100.0     ┆ 10         ┆ 0            ┆ 10       │
# │ chr1 ┆ 13284 ┆ 13284 ┆ 100.0     ┆ 14         ┆ 0            ┆ 14       │
# │ chr1 ┆ 13302 ┆ 13302 ┆ 100.0     ┆ 10         ┆ 0            ┆ 10       │
# │ chr1 ┆ 13303 ┆ 13303 ┆ 92.857143 ┆ 13         ┆ 1            ┆ 14       │
# │ chr1 ┆ 13418 ┆ 13418 ┆ 0.0       ┆ 0          ┆ 11           ┆ 11       │
# └──────┴───────┴───────┴───────────┴────────────┴──────────────┴──────────┘

# %%
mdata = epykit.core.MethylData(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mdata = epykit.core.MethylData(df)
#
# File D:\Coding\Projeler\methyl_lib\epykit\src\epykit\core\methyldata.py:79, in MethylData.__init__(self, adata)
#      78 def __init__(self, adata: "ad.AnnData") -> None:
# ---> 79     _validate_adata(adata)
#      80     self._adata = adata
#
# File D:\Coding\Projeler\methyl_lib\epykit\src\epykit\core\methyldata.py:417, in _validate_adata(adata)
#     415 """Validate that an AnnData object has the required structure."""
#     416 required_layers = {"coverage", "methylated_counts"}
# --> 417 missing_layers = required_layers - set(adata.layers.keys())
#     418 if missing_layers:
#     419     raise ValueError(
#     420         f"AnnData is missing required layers: {missing_layers}. "
#     421         "Use epykit.io.read_samples() or epykit.io.build_anndata() "
# ...
